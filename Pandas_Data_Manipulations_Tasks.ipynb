# %% [markdown]
# # How to complete this assignment
# First, download [this Kaggle dataset](https://www.kaggle.com/hugomathien/soccer) and extract *sqlite* database. You may need to register at https://www.kaggle.com/ beforehand. Then complete 15 graded tasks below, the score is given in brackets. Finally submit the resulting `.ipynb` file to rs-app Auto-test.
#
# - Do not delete or rename the variables given before the inscription `#your code here`, they are needed for the correct verification.
# - Do not change the code in the last Notebook cell, it is required for the server check.
# - Your Notebook must run completely without errors to be graded! Please check everything before submission by going *Cell -> Run All*

# %% [markdown]
# ## Some important notes
# - If you need to **calculate the number of "something"** that means we expect you to assign an Integer to the given variable
# - If you need to **make a list of "something"** we expect you to assign a Python list with appropriate values to the given variable
# - If you need to find a **specifiс player, day of the week, team, etc.** we expect you to assign a String with the full name of the entity to the given variable (`player_name`, day of week full name, `team_name`, etc.)

# %%
import sqlite3
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_column', None)

# %%
# Leave that code unchanged, it is required for the server check!
db = sqlite3.connect(os.environ.get("DB_PATH") or 'database.sqlite')

# %%
# You may load the data from SQL table directly to the Pandas dataframe as
player_data = pd.read_sql("SELECT * FROM Player;", db)
league_data = pd.read_sql("SELECT * FROM League;", db)
match_data = pd.read_sql("SELECT * FROM Match;", db)
player_att_data = pd.read_sql("SELECT * FROM Player_Attributes;", db)
team_data = pd.read_sql("SELECT * FROM Team;", db)

# %%
player_data.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %% [markdown]
# **Task 1 (0.25 point).** Calculate the number of players with a height between 180 and 190 inclusive

# %%
players_180_190 = player_data[(player_data.height >= 180) & (player_data.height <= 190)].shape[0]

# %% [markdown]
# **Task 2 (0.25 point).** Calculate the number of players born in 1980. <br>
# **Hint:** you may want to cast your 'birthday' column to DateTime type by [pandas.to_datetime](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
players_1980 = player_data[pd.to_datetime(player_data.birthday).dt.strftime('%Y') == '1980'].shape[0]

# %% [markdown]
# **Task 3 (0.25 point).** Make a list of the top 10 players with the highest weight sorted in descending order. If there are several players with the same weight put them in the lexicographic order by name.

# %%
highest_players = player_data.sort_values(by=['weight', 'player_name'], ascending=(False, True)).head(10)['player_name'].values.tolist()

# %% [markdown]
# **Task 4 (0.5 point).** Make a list of tuples containing years along with the number of players born in that year from 1980 up to 1990. <br>
# **Structure example**: [(1980, 123), (1981, 140) ..., (1990, 83)] -> There were born 123 players in 1980, there were born 140 players in 1981 and etc.

# %%
num_by_year = player_data[(pd.to_datetime(player_data.birthday).astype('datetime64[Y]') >= '1980') & \
            (pd.to_datetime(player_data.birthday).astype('datetime64[Y]') <= '1990')] \
            .groupby(pd.to_datetime(player_data.birthday).astype('datetime64[Y]')).size()
years_born_players = list(zip(num_by_year.index.year, num_by_year))

# %% [markdown]
# **Task 5 (0.5 point).** Calculate the mean and the standard deviation of the players' **height** with the name **Adriano**. <br>
# **Note:** Name is represented by the first part of `player_name`.

# %%
adrianos_heights = player_data[player_data.player_name.str.startswith('Adriano')]['height']
adriano_mean, adriano_std = adrianos_heights.mean(), adrianos_heights.std()

# %% [markdown]
# **Task 6 (0.75 point).** How many players were born on each day of the week? Find the day of the week with the minimum number of players born.

# %%
dow_with_min_players_born = player_data.groupby(pd.to_datetime(player_data.birthday).dt.strftime('%A')) \
                                        .size().sort_values().index[0]

# %% [markdown]
# **Task 7 (0.75 point).** Find a league with the most matches in total. If there are several leagues with the same amount of matches, take the first in the lexical order.

# %%
match_data.sample(5)
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 20333  20334       19694      19694  2010/2011     37  2011-05-11 00:00:00
# 4442    4443        1729       1729  2015/2016     14  2015-11-29 00:00:00
# 2425    2426        1729       1729  2009/2010     38  2010-05-09 00:00:00
# 6379    6380        4769       4769  2012/2013     18  2012-12-16 00:00:00
# 18582  18583       17642      17642  2011/2012      7  2011-10-02 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 20333       1005036              9927              8597               1
# 4442        1988844              8650             10003               1
# 2425         659376             10260             10194               4
# 6379        1216982              8481              9827               1
# 18582       1042883             10214              2033               1
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# ...

# %%
num_of_mathes_for_each_league = match_data.groupby(match_data.league_id).size().sort_values(ascending=False) \
                                            .rename('matches')
league_most_matches = pd.merge(num_of_mathes_for_each_league, league_data[['id', 'name']], right_on='id', left_index=True) \
                        .sort_values(by=['matches', 'name'], ascending=(False, True)).iloc[0]['name']

# %% [markdown]
# **Task 8 (1.25 point).** Find a player who participated in the largest number of matches during the whole match history. Assign a `player_name` to the given variable

# %%
players_id, counts = np.unique(match_data.loc[:,'home_player_1' : 'away_player_11'].dropna().values, return_counts=True)
max_matches_player = player_data[player_data.player_api_id == players_id[counts.argmax()]].iloc[0]['player_name']

# %% [markdown]
# **Task 9 (1.5 point).** List top-5 tuples of most correlated **player's characteristics** in the descending order of the absolute [Pearson's coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient) value.
#
# **Note 1:** Players characteristics are all the columns in `Player_Attributes` table except `[id, player_fifa_api_id, player_api_id, date, preferred_foot, attacking_work_rate, defensive_work_rate]`). <br>
# **Note 2:** Exclude duplicated pairs from the list. E.g. ('gk_handling', 'gk_reflexes') and ('gk_reflexes', 'gk_handling') are duplicates, leave just one of them in the resulting list.
#
# **Hint:** You may use [dataframe.corr()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) for calculating pairwise Pearson correlation.

# %%
x = player_att_data.loc[:, ~player_att_data.columns.isin(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'preferred_foot', \
                                                          'attacking_work_rate', 'defensive_work_rate'])].corr()
top_correlated_features = x.where(np.triu(np.ones(x.shape), k=1).astype(bool)).stack() \
                            .sort_values(ascending=False)[:5].index.tolist()

# %% [markdown]
# **Task 10 (2 points).** Find top-5 most similar players to **Neymar** whose names are given. The similarity is measured as [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance) between vectors of players' characteristics (described in the task above). Put their names in a vector in ascending order by Euclidean distance and sorted by `player_name` if the distance is the same<br>
# **Note 1:** There are many records for some players in the `Player_Attributes` table. You need to take the freshest data (characteristics with the most recent `date`). <br>
# **Note 2:** Use pure values of the characteristics even if you are aware of such preprocessing technics as normalization. <br>
# **Note 3:** Please avoid using any built-in methods for calculating the Euclidean distance between vectors, think about implementing your own.

# %%
# player_att_data.loc[:, ~player_att_data.columns.isin(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'preferred_foot', \
#                                                           'attacking_work_rate', 'defensive_work_rate'])]
neymar_api_id = player_data[player_data.player_name == 'Neymar'].iloc[0]['player_api_id']
player_att_data_10 = player_att_data[:].dropna()
player_att_data_10['date'] = pd.to_datetime(player_att_data_10.date)
neymar_attr = player_att_data_10[player_att_data_10.player_api_id == neymar_api_id].sort_values(by='date', ascending=False).head(1) \
                                                                .loc[:, ~player_att_data_10.columns.isin(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'preferred_foot', \
                                                          'attacking_work_rate', 'defensive_work_rate'])]
last_measures_dates = player_att_data_10.groupby('player_api_id')['date'].max()
latest_measures = pd.merge(last_measures_dates, player_att_data_10, on=['player_api_id', 'date']).loc[:, ~player_att_data.columns.isin(['player_fifa_api_id', 'date', 'preferred_foot', \
                                                          'attacking_work_rate', 'defensive_work_rate'])]
latest_measures['euclidian_distance'] = latest_measures.loc[:, 'overall_rating':'gk_reflexes'].sub(neymar_attr.squeeze()).pow(2).sum(axis=1)
closest_players_ids = latest_measures.sort_values(by='euclidian_distance').head(6).iloc[1:]['player_api_id']
neymar_similarities = pd.merge(closest_players_ids, player_data, on='player_api_id').iloc[:]['player_name'].tolist()

# %% [markdown]
# **Task 11 (1 point).** Calculate the number of home matches played by the **Borussia Dortmund** team in **Germany 1. Bundesliga** in season **2008/2009**

# %%
bd_team_id = team_data[team_data.team_long_name == 'Borussia Dortmund'].iloc[0]['team_api_id']
bundesleague_id = league_data[league_data.name == 'Germany 1. Bundesliga'].iloc[0]['id']
borussia_bundesliga_2008_2009_matches = match_data[(match_data.season == '2008/2009') & \
                                                   (match_data.home_team_api_id == bd_team_id) & \
                                                   (match_data.league_id == bundesleague_id)].shape[0]

# %%
league_data.sample(5)
# Out:
#        id  country_id                      name
# 10  24558       24558  Switzerland Super League
# 7   17642       17642  Portugal Liga ZON Sagres
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 4   10257       10257             Italy Serie A

# %%
team_data.sample(7)
# Out:
#         id  team_api_id  team_fifa_api_id       team_long_name team_short_name
# 197  31925         8245          111083.0        Korona Kielce             KKI
# 205  35283         9773             236.0             FC Porto             POR
# 70    9548         9847              73.0  Paris Saint-Germain             PSG
# 258  43042         8634             241.0         FC Barcelona             BAR
# 289  49120        10179          110770.0              FC Sion             SIO
# 162  26553         8464            1910.0               N.E.C.             NEC
# 195  31457         8028          111086.0        Piast Gliwice             PIG

# %%
match_data.sample(7)
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 25089  25090       24558      24558  2010/2011      8  2010-09-12 00:00:00
# 17020  17021       15722      15722  2013/2014     20  2013-12-06 00:00:00
# 16167  16168       15722      15722  2009/2010      5  2009-08-28 00:00:00
# 57        58           1          1  2008/2009     15  2008-12-06 00:00:00
# 10690  10691       10257      10257  2009/2010     14  2009-11-29 00:00:00
# 4164    4165        1729       1729  2014/2015     23  2015-02-01 00:00:00
# 16521  16522       15722      15722  2011/2012     19  2012-02-25 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 25089        845061              7955             10190               0
# 17020       1468016              8028              8245               1
# 16167        673738              8028              8242               2
# 57           492692              9986              8203               1
# ...

# %% [markdown]
# **Task 12 (1 point).** Find a team having the most matches (both home and away!) in the **Germany 1. Bundesliga** in **2008/2009** season. Return number of matches.

# %%
away_matches = match_data[(match_data.season == '2008/2009') & (match_data.league_id == bundesleague_id)] \
                        .groupby('away_team_api_id').size()
home_matches = match_data[(match_data.season == '2008/2009') & (match_data.league_id == bundesleague_id)] \
                        .groupby('home_team_api_id').size()
team_most_matches_bundesliga_2008_2009 = away_matches.add(home_matches).sort_values(ascending=False).iloc[0]

# %% [markdown]
# **Task 13 (1 point).** Count total number of **Arsenal** matches (both home and away!) in the **2015/2016** season which they have won. <br><br>
# **Note:** Winning a game means scoring **more** goals than an opponent.

# %%
arsenal_id = team_data[team_data.team_long_name == 'Arsenal'].iloc[0]['team_api_id']
num_home_won_mathes = match_data[(match_data.season == '2015/2016') & (match_data.home_team_api_id == arsenal_id) & \
                                 (match_data.home_team_goal > match_data.away_team_goal)].shape[0]
num_away_won_mathes = match_data[(match_data.season == '2015/2016') & (match_data.away_team_api_id == arsenal_id) & \
                                 (match_data.away_team_goal > match_data.home_team_goal)].shape[0]
arsenal_won_matches_2015_2016 = num_home_won_mathes + num_away_won_mathes

# %% [markdown]
# **Task 14 (2 points).** Find a team with the highest win rate in the **2015/2016** season. Win rate means won matches / all matches. If there are several teams with the highest win rate return the first by name in lexical order

# %%
won_at_home = match_data[(match_data.season == '2015/2016') & (match_data.home_team_goal > match_data.away_team_goal)] \
                        .groupby('home_team_api_id').size()
won_away = match_data[(match_data.season == '2015/2016') & (match_data.home_team_goal < match_data.away_team_goal)] \
                        .groupby('away_team_api_id').size()
all_at_home = match_data[match_data.season == '2015/2016'].groupby('home_team_api_id').size()
all_away = match_data[match_data.season == '2015/2016'].groupby('away_team_api_id').size()
id_team_highest_winrate = won_at_home.add(won_away).divide(all_at_home.add(all_away)).sort_values(ascending=False).index[0]
team_highest_winrate_2015_2016 = team_data[team_data.team_api_id == id_team_highest_winrate].iloc[0]['team_long_name']

# %% [markdown]
# **Task 15 (2 points).** Determine the team with the maximum days' gap between matches in **England Premier League 2010/2011 season**. Return number of days in that gap. <br>
# **Note**: a *gap* means the number of days between two consecutive matches of the same team.

# %%
eng_league_id = league_data[league_data.name == 'England Premier League'].iloc[0]['id']
matches_eng_league = match_data[(match_data.season == '2010/2011') & (match_data.league_id == eng_league_id)]
home_matches_eng = matches_eng_league[['date','home_team_api_id']].rename(columns={'home_team_api_id': 'team_api_id'}) 
away_matches_eng = matches_eng_league[['date','away_team_api_id']].rename(columns={'away_team_api_id': 'team_api_id'})
team_date = pd.concat([home_matches_eng, away_matches_eng])
team_date['date'] = pd.to_datetime(team_date['date'])
gaps = team_date.sort_values(by=['team_api_id', 'date'], ascending=(True, True)).diff()
highest_gap_england_2010_2011 = gaps[gaps.team_api_id == 0].sort_values(by='date', ascending=False).iloc[0]['date'].days

# %% [markdown]
# ### Warning! Do not change anything in the area below

# %%
with open('student_answers.txt', 'w') as file:
    file.write(f"{players_180_190}\n")
    file.write(f"{players_1980}\n")
    file.write(f"{highest_players}\n")
    file.write(f"{years_born_players}\n")
    file.write(f"{round(adriano_mean, 3)} {round(adriano_std, 3)}\n")
    file.write(f"{dow_with_min_players_born}\n")
    file.write(f"{league_most_matches}\n")
    file.write(f"{max_matches_player}\n")
    file.write(f"{';'.join(['%s,%s' % tup for tup in top_correlated_features])};\n")
    file.write(f"{neymar_similarities}\n")
    file.write(f"{borussia_bundesliga_2008_2009_matches}\n")
    file.write(f"{team_most_matches_bundesliga_2008_2009}\n")
    file.write(f"{arsenal_won_matches_2015_2016}\n")
    file.write(f"{team_highest_winrate_2015_2016}\n")
    file.write(f"{highest_gap_england_2010_2011}\n")
