# %% [markdown]
# ### !!! Use [this link](https://nbviewer.org/github/kesepkina/RS-ML-Cross-Check-2/blob/main/5_Classification_Linear_KNN.ipynb) to see all the Outputs !!!

# %% [markdown]
# # Classification. Linear models and KNN

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import plot_confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
import warnings
# to ignore FutureWarning by plotting Confusion Matrx
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Part 1: Implementing Logistic Regression

# %% [markdown]
# In this task you need to implement Logistic Regression with l2 regularization using gradient descent algorithm.

# %% [markdown]
# Logistic Regression loss:
# $$ L(w) = \dfrac{1}{N}\sum_{i=1}^N \log(1 + e^{-\langle w, x_i \rangle y_i}) + \frac{1}{2C} \lVert w \rVert^2  \to \min_w$$
# $$\langle w, x_i \rangle = \sum_{j=1}^n w_{j}x_{ij} + w_{0},$$ $$ y_{i} \in \{-1, 1\}$$ where $n$ is the number of features and $N$ is the number of samples.

# %% [markdown]
# Gradient descent step:
# $$w^{(t+1)} := w^{(t)} + \dfrac{\eta}{N}\sum_{i=1}^N y_ix_i \Big(1 - \dfrac{1}{1 + exp(-\langle w^{(t)}, x_i \rangle y_i)}\Big) - \eta \frac{1}{C} w,$$
# where $\eta$ is the learning rate.

# %% [markdown]
# **(2 points)** Implement the algorithm and use it to classify the digits (https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) into "even" and "odd" categories. "Even" and "Odd" classes  should correspond to {-1, 1} labels.

# %% [markdown]
# Stopping criteria: either the number of iterations exceeds *max_iter* or $||w^{(t+1)} - w^{(t)}||_2 < tol$.

# %%
from sklearn.exceptions import NotFittedError

# %%
class CustomLogisticRegression:
    _estimator_type = "classifier"
    
    def __init__(self, eta=0.001, max_iter=1000, C=1.0, tol=1e-5, random_state=42, zero_init=False):
        """Logistic Regression classifier.
        
        Args:
            eta: float, default=0.001
                Learning rate.
            max_iter: int, default=1000
                Maximum number of iterations taken for the solvers to converge.
            C: float, default=1.0
                Inverse of regularization strength; must be a positive float.
                Smaller values specify stronger regularization.
            tol: float, default=1e-5
                Tolerance for stopping criteria.
            random_state: int, default=42
                Random state.
            zero_init: bool, default=False
                Zero weight initialization.
        """
        self.eta = eta
        self.max_iter = max_iter
        self.C = C
        self.tol = tol
        self.random_state = np.random.RandomState(seed=random_state)
        self.zero_init = zero_init
        self.weights_ = []
        self.loss_history = []
         
    def get_sigmoid(self, X, weights):
        """Compute the sigmoid value."""
        # <your code>
        return 1 / (1 + np.exp(- X @ weights))
    
    def get_loss(self, x, weights, y):
        """Calculate the loss."""
        # <your code>
        return np.mean(np.log(1 + np.exp(- x @ weights * y))) + 1 / (2 * self.C) * np.linalg.norm(weights, 2)
     
    def fit(self, X, y):
        """Fit the model.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
            y: numpy array of shape (n_samples,)
                Target vector.        
        """
        loss_history = []
        X_ext = np.hstack([np.ones((X.shape[0], 1)), X]) # a constant feature is included to handle intercept
        num_features = X_ext.shape[1]
        if self.zero_init:
            self.weights_ = np.zeros(num_features) 
        else:
            weight_threshold = 1.0 / (2 * num_features)
            self.weights_ = self.random_state.uniform(low=-weight_threshold,
                                                      high=weight_threshold, size=num_features) # random weight initialization
        
        for i in range(self.max_iter):
            delta = self.weights_ / self.C - np.mean(y * X_ext.T * (1 - 1 / (1 + np.exp(- (X_ext @ self.weights_) * y))), \
                                                    axis=-1) # <your code>
            self.weights_ -= self.eta * delta
            loss_history.append(self.get_loss(X_ext, self.weights_, y))
            if np.linalg.norm(self.eta * delta, 2) < self.tol:
                break
        return loss_history
     
    def predict_proba(self, X):
        """Predict positive class probabilities.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
        Returns:
            y: numpy array of shape (n_samples,)
                Vector containing positive class probabilities.
        """
        X_ext = np.hstack([np.ones((X.shape[0], 1)), X])
        if hasattr(self, 'weights_'):
            return self.get_sigmoid(X_ext, self.weights_)
        else: 
            raise NotFittedError("CustomLogisticRegression instance is not fitted yet")
    
    def predict(self, X):
        """Predict classes.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
        Returns:
            y: numpy array of shape (n_samples,)
                Vector containing predicted class labels.
        """
        # <your code>
        X_ext = np.hstack([np.ones((X.shape[0], 1)), X])
        return np.where(self.get_sigmoid(X_ext, self.weights_) > 0.5, 1, -1)

# %%
from sklearn import datasets
from sklearn import metrics

# %%
X, y = datasets.load_digits(n_class=10, return_X_y=True)

_, axes = plt.subplots(nrows=3, ncols=7, figsize=(10, 5))
for ax, image, label in zip(axes.flatten(), X, y):
    ax.set_axis_off()
    ax.imshow(image.reshape((8, 8)), cmap=plt.cm.gray_r if label % 2 else plt.cm.afmhot_r)
    ax.set_title(label)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)
# y_train = "<your code>"
#y_test = "<your code>"
y_train = (y_train % 2) * 2 - 1
y_test = (y_test % 2) * 2 - 1

# %%
assert (np.unique(y_train) == [-1, 1]).all()
assert (np.unique(y_test) == [-1, 1]).all()

# %%
def fit_evaluate(clf, X_train, y_train, X_test, y_test):
    clf.fit(X_train, y_train)
    disp = metrics.plot_confusion_matrix(clf, X_test, y_test, normalize='true')
    disp.figure_.suptitle("Confusion Matrix")
    plt.show()
    
    return metrics.accuracy_score(y_pred=clf.predict(X_train), y_true=y_train), \
           metrics.accuracy_score(y_pred=clf.predict(X_test), y_true=y_test)

# %%
lr_clf = CustomLogisticRegression(max_iter=1, zero_init=True)

# %%
assert np.allclose(lr_clf.get_sigmoid(np.array([[0.5, 0, 1.0], [0.3, 1.3, 1.0]]), np.array([0.5, -0.5, 0.1])),
                   np.array([0.58662, 0.40131]))

# %%
loss_history = lr_clf.fit(X_train, y_train)

# %%
assert np.allclose(lr_clf.weights_, np.array([ 3.1000e-06,  0.0000e+00,  4.1800e-05,  5.4770e-04,  2.2130e-04,
        4.8750e-04,  1.3577e-03,  5.9780e-04,  5.6400e-05, -7.0000e-07,
        1.6910e-04,  2.5190e-04, -4.3700e-04,  3.6190e-04,  1.0049e-03,
        4.2280e-04,  2.5700e-05,  3.0000e-07, -1.1500e-05, -7.2440e-04,
       -2.6200e-04,  8.7540e-04,  4.1540e-04, -8.4200e-05, -5.2000e-06,
        0.0000e+00, -2.2160e-04, -5.7130e-04,  9.8570e-04,  1.3507e-03,
        5.0210e-04, -1.7050e-04, -1.0000e-06,  0.0000e+00, -6.7810e-04,
       -1.0515e-03, -4.4500e-05,  3.7160e-04,  4.2100e-04, -8.1800e-05,
        0.0000e+00, -5.2000e-06, -5.3410e-04, -2.0393e-03, -8.4310e-04,
        1.0400e-04, -1.2390e-04, -1.7880e-04, -1.3200e-05, -4.5000e-06,
       -9.4300e-05, -1.1127e-03, -5.0900e-04, -2.1850e-04, -5.6050e-04,
       -3.9560e-04, -1.7700e-05, -3.0000e-07,  2.6800e-05,  6.3920e-04,
        1.8090e-04, -7.3660e-04, -5.3930e-04, -3.7060e-04, -2.8200e-05]), atol=1e-5)

# %%
model = CustomLogisticRegression()

# %%
train_acc, test_acc = fit_evaluate(model, X_train, y_train, X_test, y_test)

# %%
train_acc, test_acc
# Out:
# (0.9109255393180237, 0.9388888888888889)

# %%
assert min(train_acc, test_acc) > 0.9

# %% [markdown]
# **(0.5 points)** Visualize the loss history.

# %%
## your code
loss_history = []
model = CustomLogisticRegression()
loss_history.append(model.fit(X_train, y_train))

# %%
def plot_loss_history(loss_history, learning_rates, title, xlabel='Iterations', ylabel='Loss'):
    plt.figure(figsize=(9, 4.5))
    for i in range(len(loss_history)):
        plt.plot(loss_history[i], label='LR={:.3f}'.format(learning_rates[i]))
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)      
    plt.legend(loc='center right')        
    plt.show()

# %%
plot_loss_history(loss_history, [0.001], 'Loss history on the train set', ylabel='LogLoss')

# %%
np.argmin(loss_history)
# Out:
# 379

# %% [markdown]
# **(0.5 points)** Try different learning rates and compare the results. How does the learning rate influence the convergence?

# %%
## your code
loss_history = []
learning_rates = np.arange(0.001, 0.01, 0.001)
for lr in learning_rates[:4]:
    model = CustomLogisticRegression(eta=lr)
    loss_history.append(model.fit(X_train, y_train))
plot_loss_history(loss_history, learning_rates[:5], 'Loss history on the train set', ylabel='LogLoss')

# %%
loss_history_short = [array[:125] for array in loss_history]

# %%
plot_loss_history(loss_history_short, learning_rates[:4], 'Loss history on the train set (first 125 iterations)', ylabel='LogLoss')

# %%
## your code
for lr in learning_rates[4:]:
    model = CustomLogisticRegression(eta=lr)
    loss_history.append(model.fit(X_train, y_train))
plot_loss_history(loss_history[4:], learning_rates[4:], 'Loss history on the train set', ylabel='LogLoss')

# %%
loss_history_short = [array[:125] for array in loss_history[4:]]

# %%
plot_loss_history(loss_history_short, learning_rates[4:], 'Loss history on the train set (first 125 iterations)', ylabel='LogLoss')

# %%
min_losses = [min(loss) for loss in loss_history]
iterations = [np.argmin(loss) for loss in loss_history]
results = pd.DataFrame(data={'Min loss': min_losses, 'Iterations to reach': iterations}, index=learning_rates)
results.style.highlight_min(subset=['Min loss', 'Iterations to reach'])
# Out:
# <style type="text/css">
# #T_b5f8a_row0_col0, #T_b5f8a_row5_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b5f8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5f8a_level0_col0" class="col_heading level0 col0" >Min loss</th>
#       <th id="T_b5f8a_level0_col1" class="col_heading level0 col1" >Iterations to reach</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5f8a_level0_row0" class="row_heading level0 row0" >0.001000</th>
#       <td id="T_b5f8a_row0_col0" class="data row0 col0" >0.386215</td>
#       <td id="T_b5f8a_row0_col1" class="data row0 col1" >379</td>
#     </tr>
#     <tr>
#       <th id="T_b5f8a_level0_row1" class="row_heading level0 row1" >0.002000</th>
#       <td id="T_b5f8a_row1_col0" class="data row1 col0" >0.386226</td>
#       <td id="T_b5f8a_row1_col1" class="data row1 col1" >189</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# > Learning rates till 0.006 converge faster with decreasing of their value. But the min loss gets higher for every increase in learning rate. Especially after learning rate == 0.007.
#
# > Furthermore we can observe graph jumps in the first 15 iterations for learning rate >= 0.004.

# %% [markdown]
# **(0.5 points)** Try different regularization parameter values and compare the model quality.

# %%
def fit_evaluate_acc_f1(clf, X_train, y_train, X_test, y_test):
    clf.fit(X_train, y_train)
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    return metrics.accuracy_score(y_pred=y_train_pred, y_true=y_train), \
           metrics.accuracy_score(y_pred=y_test_pred, y_true=y_test), \
           metrics.f1_score(y_pred=clf.predict(X_train), y_true=y_train), \
           metrics.f1_score(y_pred=y_test_pred, y_true=y_test)

# %%
## your code
models_by_C = pd.DataFrame(columns=['C', 'Train accuracy', 'Test accuracy', 'Train f1', 'Test f1'])
for C in np.arange(0.6, 3.5, 0.2):
    model = CustomLogisticRegression(C=C)
    train_acc, test_acc, train_f1, test_f1 = fit_evaluate_acc_f1(model, X_train, y_train, X_test, y_test)
    new_row = pd.DataFrame(data={'C':f'{C:.1f}', 'Train accuracy':train_acc, 'Test accuracy':test_acc, \
                                 'Train f1':train_f1, 'Test f1':test_f1}, index=[C])
    models_by_C = pd.concat([models_by_C, new_row], ignore_index=True)
models_by_C.style.highlight_max(subset=['Train accuracy', 'Test accuracy', 'Train f1', 'Test f1'])
# Out:
# <style type="text/css">
# #T_b7bc4_row5_col2, #T_b7bc4_row5_col4, #T_b7bc4_row6_col2, #T_b7bc4_row6_col4, #T_b7bc4_row7_col2, #T_b7bc4_row7_col4, #T_b7bc4_row8_col2, #T_b7bc4_row8_col4, #T_b7bc4_row9_col2, #T_b7bc4_row9_col4, #T_b7bc4_row10_col1, #T_b7bc4_row10_col2, #T_b7bc4_row10_col3, #T_b7bc4_row10_col4, #T_b7bc4_row11_col1, #T_b7bc4_row11_col2, #T_b7bc4_row11_col3, #T_b7bc4_row11_col4, #T_b7bc4_row12_col1, #T_b7bc4_row12_col2, #T_b7bc4_row12_col3, #T_b7bc4_row12_col4, #T_b7bc4_row13_col1, #T_b7bc4_row13_col2, #T_b7bc4_row13_col3, #T_b7bc4_row13_col4, #T_b7bc4_row14_col1, #T_b7bc4_row14_col2, #T_b7bc4_row14_col3, #T_b7bc4_row14_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b7bc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7bc4_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_b7bc4_level0_col1" class="col_heading level0 col1" >Train accuracy</th>
# ...

# %% [markdown]
# > Model quality raises with raising of regularization parameter C untill C=2.6. After that model quality parameters doesn't change.

# %% [markdown]
# **(0.5 points)** Compare zero initialization and random initialization.

# %%
## your code
models_by_init = pd.DataFrame(columns=['Initialization type', 'Train accuracy', 'Test accuracy', 'Train f1', 'Test f1'])

model = CustomLogisticRegression(zero_init=True)
train_acc, test_acc, train_f1, test_f1 = fit_evaluate_acc_f1(model, X_train, y_train, X_test, y_test)
new_row = pd.DataFrame(data={'Initialization type':'zero', 'Train accuracy':train_acc, 'Test accuracy':test_acc, \
                             'Train f1':train_f1, 'Test f1':test_f1}, index=[0])
models_by_init = pd.concat([models_by_init, new_row], ignore_index=True)

model = CustomLogisticRegression(random_state=42)
train_acc, test_acc, train_f1, test_f1 = fit_evaluate_acc_f1(model, X_train, y_train, X_test, y_test)
new_row = pd.DataFrame(data={'Initialization type':'random (seed==42)', 'Train accuracy':train_acc, 'Test accuracy':test_acc, \
                             'Train f1':train_f1, 'Test f1':test_f1}, index=[0])
models_by_init = pd.concat([models_by_init, new_row], ignore_index=True)

model = CustomLogisticRegression(random_state=21)
train_acc, test_acc, train_f1, test_f1 = fit_evaluate_acc_f1(model, X_train, y_train, X_test, y_test)
new_row = pd.DataFrame(data={'Initialization type':'random (seed==21)', 'Train accuracy':train_acc, 'Test accuracy':test_acc, \
                             'Train f1':train_f1, 'Test f1':test_f1}, index=[0])
models_by_init = pd.concat([models_by_init, new_row], ignore_index=True)

model = CustomLogisticRegression(random_state=84)
train_acc, test_acc, train_f1, test_f1 = fit_evaluate_acc_f1(model, X_train, y_train, X_test, y_test)
new_row = pd.DataFrame(data={'Initialization type':'random (seed==84)', 'Train accuracy':train_acc, 'Test accuracy':test_acc, \
                             'Train f1':train_f1, 'Test f1':test_f1}, index=[0])
models_by_init = pd.concat([models_by_init, new_row], ignore_index=True)

models_by_init.style.highlight_max(subset=['Train accuracy', 'Test accuracy', 'Train f1', 'Test f1'])
# Out:
# <style type="text/css">
# #T_0d301_row0_col1, #T_0d301_row0_col2, #T_0d301_row0_col4, #T_0d301_row1_col2, #T_0d301_row2_col2, #T_0d301_row2_col4, #T_0d301_row3_col1, #T_0d301_row3_col2, #T_0d301_row3_col3, #T_0d301_row3_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0d301">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d301_level0_col0" class="col_heading level0 col0" >Initialization type</th>
#       <th id="T_0d301_level0_col1" class="col_heading level0 col1" >Train accuracy</th>
#       <th id="T_0d301_level0_col2" class="col_heading level0 col2" >Test accuracy</th>
#       <th id="T_0d301_level0_col3" class="col_heading level0 col3" >Train f1</th>
#       <th id="T_0d301_level0_col4" class="col_heading level0 col4" >Test f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d301_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# > All the initializations have the same test accuracy, but other quality measures are better for random initialization with random seed == 84. Random initializations with seed 21 and 42 have a little bit worser result.

# %% [markdown]
# ## Part 2: Implementing KNN Classifier

# %% [markdown]
# In this task you need to implement weighted K-Neighbors Classifier.

# %% [markdown]
# Recall that training a KNN classifier is simply memorizing a training sample.
#
# The process of applying a classifier for one object is to find the distances from it to all objects in the training data, then select the k nearest objects (neighbors) and return the most common class among these objects.

# %% [markdown]
# You can also give the nearest neighbors weights in accordance with the distance of the object to them. In the simplest case (as in your assignment), you can set the weights inversely proportional to that distance.
#
# $$w_{i} = \frac{1}{d_{i} + eps},$$
#
# where $d_{i}$ is the distance between object and i-th nearest neighbor and $eps$ is the small value to prevent division by zero.
#
# In case of 'uniform' weights, all k nearest neighbors are equivalent (have equal weight, for example $w_{i} = 1, \forall i \in(1,k)$).

# %% [markdown]
# To predict the probability of classes, it is necessary to normalize the weights of each class, dividing them by the sum:
#
# $$p_{i} = \frac{w_{i}}{\sum_{j=1}^{c}w_{j}},$$
#
# where $p_i$ is probability of i-th class and $c$ is the number of classes.

# %% [markdown]
# **(2 points)** Implement the algorithm and use it to classify the digits. By implementing this algorithm, you will be able to classify numbers not only into "even" or "odd", but into their real representation.

# %%
class CustomKNeighborsClassifier:
    _estimator_type = "classifier"
    
    def __init__(self, n_neighbors=5, weights='uniform', eps=1e-9):
        """K-Nearest Neighbors classifier.
        
        Args:
            n_neighbors: int, default=5
                Number of neighbors to use by default for :meth:`kneighbors` queries.
            weights : {'uniform', 'distance'} or callable, default='uniform'
                Weight function used in prediction.  Possible values:
                - 'uniform' : uniform weights.  All points in each neighborhood
                  are weighted equally.
                - 'distance' : weight points by the inverse of their distance.
                  in this case, closer neighbors of a query point will have a
                  greater influence than neighbors which are further away.
            eps : float, default=1e-5
                Epsilon to prevent division by 0 
        """
        self.n_neighbors = n_neighbors
        self.weights = weights
        self.eps = eps
        
    
    def get_pairwise_distances(self, X, Y):
        """
        Returnes matrix of the pairwise distances between the rows from both X and Y.
        Args:
            X: numpy array of shape (n_samples, n_features)
            Y: numpy array of shape (k_samples, n_features)
        Returns:
            P: numpy array of shape (n_samples, k_samples)
                Matrix in which (i, j) value is the distance 
                between i'th row from the X and j'th row from the Y.
        """
        # <your code>
        P = []
        for x in X:
            new_row = []
            for y in Y:
                new_row.append(np.linalg.norm(x-y))
            P.append(new_row)
        P = np.array(P)
        return P
    
    
    def get_class_weights(self, y, weights):
        """
        Returns a vector with sum of weights for each class 
        Args:
            y: numpy array of shape (n_samles,)
            weights: numpy array of shape (n_samples,)
                The weights of the corresponding points of y.
        Returns:
            p: numpy array of shape (n_classes)
                Array where the value at the i-th position 
                corresponds to the weight of the i-th class.
        """
        # <your code>
        
        class_weights = pd.DataFrame(data={'class':y, 'weights':weights}).groupby('class').sum().reindex(self.classes_) \
                                                                            .fillna(0).to_numpy().reshape(-1)
        return class_weights
            
        
    def fit(self, X, y):
        """Fit the model.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
            y: numpy array of shape (n_samples,)
                Target vector.        
        """
        self.points = X
        self.y = y
        self.classes_ = np.unique(y)
        
        
    def predict_proba(self, X):
        """Predict positive class probabilities.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
        Returns:
            y: numpy array of shape (n_samples, n_classes)
                Vector containing positive class probabilities.
        """
        if hasattr(self, 'points'):
            P = self.get_pairwise_distances(X, self.points)
            
            weights_of_points = np.ones(P.shape)
            if self.weights == 'distance':
                weights_of_points = 1 / (P + self.eps)
                
            neighbors_args = P.argsort()[:, :self.n_neighbors]
            y = []
            for i in range(P.shape[0]):
                class_weights = self.get_class_weights(self.y[neighbors_args[i]], weights_of_points[i, neighbors_args[i]])
                sum_class_weights = np.sum(class_weights)
                y.append(class_weights / sum_class_weights)
            return np.array(y)
        
        else: 
            raise NotFittedError("CustomKNeighborsClassifier instance is not fitted yet")
            
        
    def predict(self, X):
        """Predict classes.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
        Returns:
            y: numpy array of shape (n_samples,)
                Vector containing predicted class labels.
        """
        probs = self.predict_proba(X)
        predictions = []
        for prob in probs:
            predictions.append(self.classes_[np.argmax(prob)])
        return np.array(predictions)

# %%
model = CustomKNeighborsClassifier(n_neighbors=5, weights='distance')
knn = KNeighborsClassifier(n_neighbors=5, weights='distance')

# %%
assert np.allclose(model.get_pairwise_distances(np.array([[0  , 1]  , [1, 1]]), 
                                                np.array([[0.5, 0.5], [1, 0]])),
                   np.array([[0.70710678, 1.41421356],
                             [0.70710678, 1.        ]]))

# %%
model.classes_ = ['one', 'two', 'three']
assert np.allclose(model.get_class_weights(np.array(['one', 'one', 'three', 'two']), np.array([1, 1, 0, 4])), 
                   np.array([2,4,0]))

# %%
X, y = datasets.load_digits(n_class=10, return_X_y=True)

_, axes = plt.subplots(nrows=3, ncols=7, figsize=(10, 5))
for ax, image, label in zip(axes.flatten(), X, y):
    ax.set_axis_off()
    ax.imshow(image.reshape((8, 8)), cmap=plt.cm.gray_r if label % 2 else plt.cm.afmhot_r)
    ax.set_title(label)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

# %%
model.fit(X_train, y_train)
knn.fit(X_train, list(map(str, y_train)));

# %%
assert np.allclose(model.predict_proba(X_test), knn.predict_proba(X_test))

# %%
train_acc, test_acc = fit_evaluate(model, X_train, y_train, X_test, y_test)

# %%
assert train_acc == 1
assert test_acc > 0.98

# %% [markdown]
# **(0.5 points)** Take a look at the confusion matrix and tell what numbers the model confuses and why this happens.

# %% [markdown]
# > The model confuses number 5 with 6 and 9, number 7 - with 9, number 9 - with 4 and 5.
# > It's connected with their spelling similarity.

# %% [markdown]
# **(0.5 points)** Try different n_neighbors parameters and compare the output probabilities of the model.

# %%
models_by_n_neighbors = pd.DataFrame(columns=['Num of neighbors', 'Train accuracy', 'Test accuracy'])
for n_nghbrs in range(1, 15, 2):
    print('----------------------------------------------------------------------------------------------------')
    print(f'Number of neighbors == {n_nghbrs}:')
    model = CustomKNeighborsClassifier(n_neighbors=n_nghbrs, weights='distance')
    train_acc, test_acc = fit_evaluate(model, X_train, y_train, X_test, y_test)
    new_row = pd.DataFrame(data={'Num of neighbors': n_nghbrs, 'Train accuracy':train_acc, 'Test accuracy':test_acc}, \
                                 index=[n_nghbrs])
    models_by_n_neighbors = pd.concat([models_by_n_neighbors, new_row], ignore_index=True)
models_by_n_neighbors.style.highlight_max(subset=['Train accuracy', 'Test accuracy'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 1:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 3:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 5:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 7:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 9:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 11:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 13:
# <style type="text/css">
# ...

# %% [markdown]
# We can see great accuracy by 7 neighbors, let's look also at 6 and 8.

# %%
for n_nghbrs in range(6, 9, 2):
    print('----------------------------------------------------------------------------------------------------')
    print(f'Number of neighbors == {n_nghbrs}:')
    model = CustomKNeighborsClassifier(n_neighbors=n_nghbrs, weights='distance')
    train_acc, test_acc = fit_evaluate(model, X_train, y_train, X_test, y_test)
    new_row = pd.DataFrame(data={'Num of neighbors': n_nghbrs, 'Train accuracy':train_acc, 'Test accuracy':test_acc}, \
                                 index=[n_nghbrs])
    models_by_n_neighbors = pd.concat([models_by_n_neighbors, new_row], ignore_index=True)
models_by_n_neighbors.sort_values(by='Num of neighbors').style.highlight_max(subset=['Train accuracy', 'Test accuracy'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 6:
# ----------------------------------------------------------------------------------------------------
# Number of neighbors == 8:
# <style type="text/css">
# #T_45ea0_row0_col1, #T_45ea0_row1_col1, #T_45ea0_row2_col1, #T_45ea0_row3_col1, #T_45ea0_row3_col2, #T_45ea0_row4_col1, #T_45ea0_row4_col2, #T_45ea0_row5_col1, #T_45ea0_row6_col1, #T_45ea0_row7_col1, #T_45ea0_row8_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_45ea0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45ea0_level0_col0" class="col_heading level0 col0" >Num of neighbors</th>
#       <th id="T_45ea0_level0_col1" class="col_heading level0 col1" >Train accuracy</th>
#       <th id="T_45ea0_level0_col2" class="col_heading level0 col2" >Test accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# > We see, that both models with n = 6 and 7 have the best test accuracy and predictions at the confusion matrixes.

# %% [markdown]
# **(0.5 points)** Compare both 'uniform' and 'distance' weights and share your thoughts in what situations which parameter can be better.

# %%
## your code
model = CustomKNeighborsClassifier(weights='distance')
model.fit(X_train, y_train)
train_acc_d, test_acc_d = fit_evaluate(model, X_train, y_train, X_test, y_test)

# %%
model = CustomKNeighborsClassifier(weights='uniform')
model.fit(X_train, y_train)
train_acc_u, test_acc_u = fit_evaluate(model, X_train, y_train, X_test, y_test)

# %%
pd.DataFrame(data={'Train accuracy': [train_acc_d, train_acc_u], 'Test accuracy': [test_acc_d, test_acc_u]}, index=['distance', 'uniform'])
# Out:
#           Train accuracy  Test accuracy
# distance        1.000000       0.986111
# uniform         0.989562       0.986111

# %% [markdown]
# > We got a surprising result. Both models have the same test accuracy, but model with 'distance' weights gets better train accuracy.
#
# > I suppose, it's usefull to apply distance weighting method when we have small datasets or to decrease the error in situations when some of the "neighbors" are actually too far away.

# %% [markdown]
# **(0.5 points)** Suggest another distance measurement function that could improve the quality of the classification for this task.

# %% [markdown]
# Probably it would be great to apply feature weighting to give more importance to some of the features

# %% [markdown]
# **(0.5 points)** Suggest different task and distance function that you think would be suitable for it.

# %% [markdown]
# < your thoughts >

# %% [markdown]
# ## Part 3: Synthetic Titanic Survival Prediction

# %% [markdown]
# ### Dataset
#
# Read the description here: https://www.kaggle.com/c/tabular-playground-series-apr-2021/data. Download the dataset and place it in the *data/titanic/* folder in your working directory.
# You will use train.csv for model training and validation. The test set is used for model testing: once the model is trained, you can predict whether a passenger survived or not for each passenger in the test set, and submit the predictions: https://www.kaggle.com/c/tabular-playground-series-apr-2021/overview/evaluation.

# %%
PATH = "./data/"

# %%
data = pd.read_csv(os.path.join(PATH, 'titanic', 'train.csv')).set_index('PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# PassengerId
# 0                   1       1  Oconnor, Frankie  male    NaN      2      0
# 1                   0       3       Bryan, Drew  male    NaN      0      0
# 2                   0       3    Owens, Kenneth  male   0.33      1      2
# 3                   0       3     Kramer, James  male  19.00      0      0
# 4                   1       3     Bond, Michael  male  25.00      0      0
#
#                 Ticket   Fare   Cabin Embarked
# PassengerId
# 0               209245  27.14  C12239        S
# 1                27323  13.35     NaN        S
# 2            CA 457703  71.29     NaN        S
# 3             A. 10866  13.04     NaN        S
# 4               427635   7.76     NaN        S

# %% [markdown]
# ### EDA

# %% [markdown]
# **(0.5 points)** How many females and males are there in the dataset? What about the survived passengers? Is there any relationship between the gender and the survival?

# %%
## your code

# %% [markdown]
# < your thoughts >

# %% [markdown]
# **(0.5 points)** Plot age distribution of the passengers. What is the average and the median age of survived and deceased passengers? Do age distributions differ for survived and deceased passengers? Why?

# %%
## your code

# %% [markdown]
# < your thoughts >

# %% [markdown]
# **(1 point)** Explore "passenger class" and "embarked" features. What class was "the safest"? Is there any relationship between the embarkation port and the survival? Provide the corresponding visualizations.

# %%
## your code

# %% [markdown]
# < your thoughts >

# %% [markdown]
# ### Modelling

# %% [markdown]
# **(0.5 points)** Find the percentage of missing values for each feature.

# %%
## your code

# %% [markdown]
# Think about the ways to handle these missing values for modelling and write your answer below. Which methods would you suggest? What are their advantages and disadvantages?
#
# < your thoughts >

# %% [markdown]
# **(1.5 points)** Prepare the features and train two models (KNN and Logistic Regression) to predict the survival. Compare the results. Use accuracy as a metric. Don't forget about cross-validation!

# %%
## your code

# %% [markdown]
# **(0.5 + X points)** Try more feature engineering and hyperparameter tuning to improve the results. You may use either KNN or Logistic Regression (or both).

# %%
## your code

# %% [markdown]
# Select the best model, load the test set and make the predictions. Submit them to kaggle and see the results :)
#
# **Note**. X points will depend on your kaggle public leaderboard score.
# $$ f(score) = 1.0, \ \ 0.79 \leq score < 0.80,$$
# $$ f(score) = 2.5, \ \ 0.80 \leq score < 0.81,$$
# $$ f(score) = 4.0, \ \ 0.81 \leq score $$
# Your code should generate the output submitted to kaggle. Fix random seeds to make the results reproducible.
